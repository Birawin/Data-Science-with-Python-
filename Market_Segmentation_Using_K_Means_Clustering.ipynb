# %% [markdown]
# <a href="https://colab.research.google.com/github/Birawin/Data-Science-with-Python-/blob/main/Market_Segmentation_Using_K_Means_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Market Segmentation Example**

# %% [markdown]
# **Import the Relevant Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('3.12.+Example.csv')

# %%
data.head()
# Out:
#    Satisfaction  Loyalty
# 0             4    -1.33
# 1             6    -0.28
# 2             5    -0.99
# 3             7    -0.29
# 4             4     1.06

# %%
data.tail()
# Out:
#     Satisfaction  Loyalty
# 25             9    -0.99
# 26            10     0.37
# 27             9     0.03
# 28             3    -1.36
# 29             5     0.73

# %%
plt.scatter(data['Satisfaction'], data['Loyalty'])
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
# Out:
# Text(0, 0.5, 'Loyalty')

# %% [markdown]
# **Clustering**

# %%
x = data.copy()

# %%
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %% [markdown]
# **Clustering Results**

# %%
clusters = x.copy()
clusters['cluster_pred']=kmeans.fit_predict(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(clusters['Satisfaction'],clusters['Loyalty'],c=clusters['cluster_pred'],cmap='rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')

#The Algorithm likely only considered the satisfaction as the feature.. When we cluster on the basis of a single feature, graph will likely look this (similar to a graph with a line in the middle)
# Out:
# Text(0, 0.5, 'Loyalty')

# %% [markdown]
# **Standardize the Variables**

# %%
from sklearn import preprocessing
x_scaled = preprocessing.scale(x)

#sklearn.preprocessing.scale(x) - scales (standardizes with mean 0, and standard deviation of 1 by default) each variable column separately...

# %%
x_scaled
# Out:
# array([[-0.93138063, -1.3318111 ],
#        [-0.15523011, -0.28117124],
#        [-0.54330537, -0.99160391],
#        [ 0.23284516, -0.29117733],
#        [-0.93138063,  1.05964534],
#        [-2.09560642, -1.6620122 ],
#        [ 1.39707095, -0.97159172],
#        [ 0.62092042, -0.32119561],
#        [ 0.62092042,  1.01962097],
#        [ 0.62092042,  0.67941378],
#        [ 1.39707095, -0.3412078 ],
#        [-0.54330537,  0.38923705],
#        [-0.54330537, -1.69203048],
#        [-1.70753116,  0.66940768],
#        [ 0.23284516,  0.26916393],
#        [ 1.00899568,  1.35982816],
#        [ 0.62092042,  1.37984035],
#        [ 0.23284516,  1.35982816],
#        [ 0.23284516, -0.3412078 ],
#        [ 1.00899568,  0.66940768],
#        [ 1.39707095,  1.17971847],
#        [-1.31945589, -1.69203048],
#        [-0.93138063,  1.03963316],
#        [-1.31945589, -0.96158562],
#        [-0.15523011,  1.02962706],
#        [ 1.00899568, -0.99160391],
#        [ 1.39707095,  0.36922486],
# ...

# %%
#Elbow Method

wcss = []

for i in range(1,10):
  kmeans = KMeans(i)
  kmeans.fit(x_scaled)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
print(wcss)
# Out:
# [59.999999999999986, 29.818973034723143, 17.913349527387968, 10.247181805928422, 7.85810442178556, 6.729951216531732, 5.363006425346784, 4.380320178840311, 3.8067995963754537]

# %%
plt.plot(range(1,10),wcss)
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
#Exploring Clustering Solutions & Select the Number of Clusters

kmeans_new = KMeans(4)
kmeans_new.fit(x_scaled)
clusters_new = x.copy()
clusters_new['cluster_pred'] = kmeans_new.fit_predict(x_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
clusters_new #Based On Solutions Using Standardized Data
# Out:
#     Satisfaction  Loyalty  cluster_pred
# 0              4    -1.33             0
# 1              6    -0.28             2
# 2              5    -0.99             0
# 3              7    -0.29             2
# 4              4     1.06             3
# 5              1    -1.66             0
# 6             10    -0.97             2
# 7              8    -0.32             2
# 8              8     1.02             1
# 9              8     0.68             1
# 10            10    -0.34             2
# 11             5     0.39             3
# 12             5    -1.69             0
# 13             2     0.67             3
# 14             7     0.27             2
# 15             9     1.36             1
# 16             8     1.38             1
# 17             7     1.36             1
# 18             7    -0.34             2
# 19             9     0.67             1
# 20            10     1.18             1
# 21             3    -1.69             0
# ...

# %%
plt.scatter(clusters_new['Satisfaction'],clusters_new['Loyalty'],c=clusters_new['cluster_pred'],cmap='rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')

#We have Alienated Customers (Purple), Satisfied Customers(Red), Fans(Turquoise), #Yellowish-Green (Roamers)
# Out:
# Text(0, 0.5, 'Loyalty')
